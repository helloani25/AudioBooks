# %% [markdown]
# # Local HF Endpoint Book Summarization
#
# Run this notebook locally. The tokenizer, GCS loading, chapter splitting, and result saving run on this machine. The summarization model inference runs on a Hugging Face Inference Endpoint.

# %% [markdown]
# ## Environment
#
# Before running, set these environment variables in your shell or a local `.env` file:
#
# ```bash
# export HF_TOKEN="..."
# export GOOGLE_APPLICATION_CREDENTIALS="/absolute/path/to/credentials.json"
# export GCS_BUCKET="gutenberg-books"
# ```

# %%
# %pip install -U transformers sentencepiece huggingface_hub google-cloud-storage python-dotenv torch
# Out:
# Requirement already satisfied: transformers in /Users/anithas/PycharmProjects/SystemDesign/.venv/lib/python3.14/site-packages (5.12.1)
# Requirement already satisfied: sentencepiece in /Users/anithas/PycharmProjects/SystemDesign/.venv/lib/python3.14/site-packages (0.2.1)
# Requirement already satisfied: huggingface_hub in /Users/anithas/PycharmProjects/SystemDesign/.venv/lib/python3.14/site-packages (1.20.1)
# Requirement already satisfied: google-cloud-storage in /Users/anithas/PycharmProjects/SystemDesign/.venv/lib/python3.14/site-packages (3.12.0)
# Requirement already satisfied: python-dotenv in /Users/anithas/PycharmProjects/SystemDesign/.venv/lib/python3.14/site-packages (1.2.2)
# Requirement already satisfied: torch in /Users/anithas/PycharmProjects/SystemDesign/.venv/lib/python3.14/site-packages (2.12.1)
# Requirement already satisfied: numpy>=1.17 in /Users/anithas/PycharmProjects/SystemDesign/.venv/lib/python3.14/site-packages (from transformers) (2.4.3)
# Requirement already satisfied: packaging>=20.0 in /Users/anithas/PycharmProjects/SystemDesign/.venv/lib/python3.14/site-packages (from transformers) (26.0)
# Requirement already satisfied: pyyaml>=5.1 in /Users/anithas/PycharmProjects/SystemDesign/.venv/lib/python3.14/site-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex>=2025.10.22 in /Users/anithas/PycharmProjects/SystemDesign/.venv/lib/python3.14/site-packages (from transformers) (2026.4.4)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /Users/anithas/PycharmProjects/SystemDesign/.venv/lib/python3.14/site-packages (from transformers) (0.22.2)
# Requirement already satisfied: typer in /Users/anithas/PycharmProjects/SystemDesign/.venv/lib/python3.14/site-packages (from transformers) (0.24.1)
# Requirement already satisfied: safetensors>=0.4.3 in /Users/anithas/PycharmProjects/SystemDesign/.venv/lib/python3.14/site-packages (from transformers) (0.7.0)
# Requirement already satisfied: tqdm>=4.60 in /Users/anithas/PycharmProjects/SystemDesign/.venv/lib/python3.14/site-packages (from transformers) (4.67.3)
# Requirement already satisfied: click>=8.4.0 in /Users/anithas/PycharmProjects/SystemDesign/.venv/lib/python3.14/site-packages (from huggingface_hub) (8.4.1)
# Requirement already satisfied: filelock>=3.10.0 in /Users/anithas/PycharmProjects/SystemDesign/.venv/lib/python3.14/site-packages (from huggingface_hub) (3.28.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/anithas/PycharmProjects/SystemDesign/.venv/lib/python3.14/site-packages (from huggingface_hub) (2026.2.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.1 in /Users/anithas/PycharmProjects/SystemDesign/.venv/lib/python3.14/site-packages (from huggingface_hub) (1.5.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/anithas/PycharmProjects/SystemDesign/.venv/lib/python3.14/site-packages (from huggingface_hub) (0.28.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in /Users/anithas/PycharmProjects/SystemDesign/.venv/lib/python3.14/site-packages (from huggingface_hub) (4.15.0)
# Requirement already satisfied: anyio in /Users/anithas/PycharmProjects/SystemDesign/.venv/lib/python3.14/site-packages (from httpx<1,>=0.23.0->huggingface_hub) (4.13.0)
# Requirement already satisfied: certifi in /Users/anithas/PycharmProjects/SystemDesign/.venv/lib/python3.14/site-packages (from httpx<1,>=0.23.0->huggingface_hub) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /Users/anithas/PycharmProjects/SystemDesign/.venv/lib/python3.14/site-packages (from httpx<1,>=0.23.0->huggingface_hub) (1.0.9)
# Requirement already satisfied: idna in /Users/anithas/PycharmProjects/SystemDesign/.venv/lib/python3.14/site-packages (from httpx<1,>=0.23.0->huggingface_hub) (3.11)
# Requirement already satisfied: h11>=0.16 in /Users/anithas/PycharmProjects/SystemDesign/.venv/lib/python3.14/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface_hub) (0.16.0)
# Requirement already satisfied: shellingham>=1.3.0 in /Users/anithas/PycharmProjects/SystemDesign/.venv/lib/python3.14/site-packages (from typer->transformers) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /Users/anithas/PycharmProjects/SystemDesign/.venv/lib/python3.14/site-packages (from typer->transformers) (15.0.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in /Users/anithas/PycharmProjects/SystemDesign/.venv/lib/python3.14/site-packages (from typer->transformers) (0.0.4)
# Requirement already satisfied: google-auth<3.0.0,>=2.26.1 in /Users/anithas/PycharmProjects/SystemDesign/.venv/lib/python3.14/site-packages (from google-cloud-storage) (2.49.2)
# Requirement already satisfied: google-api-core<3.0.0,>=2.27.0 in /Users/anithas/PycharmProjects/SystemDesign/.venv/lib/python3.14/site-packages (from google-cloud-storage) (2.30.3)
# Requirement already satisfied: google-cloud-core<3.0.0,>=2.4.2 in /Users/anithas/PycharmProjects/SystemDesign/.venv/lib/python3.14/site-packages (from google-cloud-storage) (2.5.1)
# Requirement already satisfied: google-resumable-media<3.0.0,>=2.7.2 in /Users/anithas/PycharmProjects/SystemDesign/.venv/lib/python3.14/site-packages (from google-cloud-storage) (2.8.2)
# Requirement already satisfied: requests<3.0.0,>=2.22.0 in /Users/anithas/PycharmProjects/SystemDesign/.venv/lib/python3.14/site-packages (from google-cloud-storage) (2.33.0)
# Requirement already satisfied: google-crc32c<2.0.0,>=1.6.0 in /Users/anithas/PycharmProjects/SystemDesign/.venv/lib/python3.14/site-packages (from google-cloud-storage) (1.8.0)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.63.2 in /Users/anithas/PycharmProjects/SystemDesign/.venv/lib/python3.14/site-packages (from google-api-core<3.0.0,>=2.27.0->google-cloud-storage) (1.74.0)
# Requirement already satisfied: protobuf<8.0.0,>=4.25.8 in /Users/anithas/PycharmProjects/SystemDesign/.venv/lib/python3.14/site-packages (from google-api-core<3.0.0,>=2.27.0->google-cloud-storage) (7.34.1)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /Users/anithas/PycharmProjects/SystemDesign/.venv/lib/python3.14/site-packages (from google-api-core<3.0.0,>=2.27.0->google-cloud-storage) (1.27.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/anithas/PycharmProjects/SystemDesign/.venv/lib/python3.14/site-packages (from google-auth<3.0.0,>=2.26.1->google-cloud-storage) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in /Users/anithas/PycharmProjects/SystemDesign/.venv/lib/python3.14/site-packages (from google-auth<3.0.0,>=2.26.1->google-cloud-storage) (46.0.7)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/anithas/PycharmProjects/SystemDesign/.venv/lib/python3.14/site-packages (from requests<3.0.0,>=2.22.0->google-cloud-storage) (3.4.6)
# Requirement already satisfied: urllib3<3,>=1.26 in /Users/anithas/PycharmProjects/SystemDesign/.venv/lib/python3.14/site-packages (from requests<3.0.0,>=2.22.0->google-cloud-storage) (2.6.3)
# Requirement already satisfied: setuptools<82 in /Users/anithas/PycharmProjects/SystemDesign/.venv/lib/python3.14/site-packages (from torch) (81.0.0)
# Requirement already satisfied: sympy>=1.13.3 in /Users/anithas/PycharmProjects/SystemDesign/.venv/lib/python3.14/site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /Users/anithas/PycharmProjects/SystemDesign/.venv/lib/python3.14/site-packages (from torch) (3.6.1)
# Requirement already satisfied: jinja2 in /Users/anithas/PycharmProjects/SystemDesign/.venv/lib/python3.14/site-packages (from torch) (3.1.6)
# Requirement already satisfied: cffi>=2.0.0 in /Users/anithas/PycharmProjects/SystemDesign/.venv/lib/python3.14/site-packages (from cryptography>=38.0.3->google-auth<3.0.0,>=2.26.1->google-cloud-storage) (2.0.0)
# Requirement already satisfied: pycparser in /Users/anithas/PycharmProjects/SystemDesign/.venv/lib/python3.14/site-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth<3.0.0,>=2.26.1->google-cloud-storage) (3.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /Users/anithas/PycharmProjects/SystemDesign/.venv/lib/python3.14/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.26.1->google-cloud-storage) (0.6.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/anithas/PycharmProjects/SystemDesign/.venv/lib/python3.14/site-packages (from rich>=12.3.0->typer->transformers) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/anithas/PycharmProjects/SystemDesign/.venv/lib/python3.14/site-packages (from rich>=12.3.0->typer->transformers) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/anithas/PycharmProjects/SystemDesign/.venv/lib/python3.14/site-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->transformers) (0.1.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/anithas/PycharmProjects/SystemDesign/.venv/lib/python3.14/site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/anithas/PycharmProjects/SystemDesign/.venv/lib/python3.14/site-packages (from jinja2->torch) (3.0.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
from __future__ import annotations

import importlib
import json
import os
import time

from dotenv import load_dotenv
from huggingface_hub import InferenceClient, create_inference_endpoint, get_inference_endpoint
from transformers import AutoTokenizer

load_dotenv()
# Out:
# True

# %%
MODEL_ID = "Qwen/Qwen2.5-7B-Instruct"
GCS_BUCKET = os.environ.get("GCS_BUCKET", "gutenberg-books")
HF_API_TOKEN = os.environ.get("HF_API_TOKEN")

os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "/Users/anithas/PycharmProjects/SystemDesign/AudioBooks/credentials.json"

if not HF_API_TOKEN:
    raise RuntimeError("Set HF_API_TOKEN in your environment or .env file.")

if not os.environ.get("GOOGLE_APPLICATION_CREDENTIALS"):
    raise RuntimeError("Set GOOGLE_APPLICATION_CREDENTIALS to your GCS service-account JSON path.")

print(f"Bucket: {GCS_BUCKET}")
print(f"Model: {MODEL_ID}")
print(f"HF_API_TOKEN: {HF_API_TOKEN}")
# Out:
# Bucket: gutenberg-books
# Model: Qwen/Qwen2.5-7B-Instruct
# HF_API_TOKEN: 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

# %%
import AudioBooks.Test.summarizer as summaries_blackwell

summaries_blackwell = importlib.reload(summaries_blackwell)

_make_gcs_client = summaries_blackwell._make_gcs_client
_load_book_record = summaries_blackwell._load_book_record
summarize_book = summaries_blackwell.summarize_book
_semantic_similarity = summaries_blackwell._semantic_similarity
_lexical_similarity = summaries_blackwell._lexical_similarity
_max_nli_contradiction = summaries_blackwell._max_nli_contradiction

gcs_client = _make_gcs_client(os.environ.get("GOOGLE_APPLICATION_CREDENTIALS"))

id_map_blob = gcs_client.bucket(GCS_BUCKET).blob("book-desc/gutenberg-id-map.json")
id_map: dict[str, int] = json.loads(id_map_blob.download_as_text(encoding="utf-8"))
all_book_ids = sorted(set(id_map.values()))

print(f"Found {len(all_book_ids)} books in GCS bucket {GCS_BUCKET!r}")
# Out:
# Found 76875 books in GCS bucket 'gutenberg-books'

# %%
# Hugging Face Inference Endpoint configuration.
# For a quick smoke test, set ENDPOINT_REPOSITORY = "gpt2" and use CPU.
# For Qwen 7B, use a GPU instance and confirm endpoint billing is enabled.
ENDPOINT_NAME = "audiobook-summary-qwen25-7b"
ENDPOINT_REPOSITORY = MODEL_ID
ENDPOINT_FRAMEWORK = "pytorch"
ENDPOINT_TASK = "text-generation"
ENDPOINT_ACCELERATOR = "gpu"
ENDPOINT_VENDOR = "aws"
ENDPOINT_REGION = "us-east-1"
ENDPOINT_INSTANCE_SIZE = "x1"
ENDPOINT_INSTANCE_TYPE = "nvidia-a100"
ENDPOINT_TYPE = "authenticated"
CREATE_ENDPOINT_IF_MISSING = True


def load_or_create_endpoint():
    try:
        endpoint = get_inference_endpoint(ENDPOINT_NAME, token=HF_API_TOKEN)
        print(f"Using existing endpoint: {ENDPOINT_NAME}")
    except Exception as exc:
        if not CREATE_ENDPOINT_IF_MISSING:
            raise
        print(f"Creating endpoint {ENDPOINT_NAME}: {exc}")
        endpoint = create_inference_endpoint(
            ENDPOINT_NAME,
            repository=ENDPOINT_REPOSITORY,
            framework=ENDPOINT_FRAMEWORK,
            task=ENDPOINT_TASK,
            accelerator=ENDPOINT_ACCELERATOR,
            vendor=ENDPOINT_VENDOR,
            region=ENDPOINT_REGION,
            instance_size=ENDPOINT_INSTANCE_SIZE,
            instance_type=ENDPOINT_INSTANCE_TYPE,
            type=ENDPOINT_TYPE,
            token=HF_API_TOKEN,
        )

    endpoint.wait()
    print(f"Endpoint URL: {endpoint.url}")
    return endpoint


endpoint = load_or_create_endpoint()
hf_client = InferenceClient(model=endpoint.url, token=HF_API_TOKEN)
# Out:
# Using existing endpoint: audiobook-summary-qwen25-7b
# Endpoint URL: https://qa8zdn4a7x5ms3kt.us-east-1.aws.endpoints.huggingface.cloud

# %%
from concurrent.futures import ThreadPoolExecutor

# Tokenizer runs locally only for prompt/chunk sizing. Model generation runs on the HF endpoint.
tokenizer = AutoTokenizer.from_pretrained(MODEL_ID, token=HF_API_TOKEN)
if tokenizer.pad_token is None:
    tokenizer.pad_token = tokenizer.eos_token or tokenizer.unk_token or "[PAD]"

# Chunks shorter than this token count are skipped (usually just headings with no body).
MIN_CHUNK_TOKENS = 20


def _truncate_at_prompt_marker(text: str) -> str:
    """Cut off any hallucinated continuation at the first ### marker."""
    idx = text.find("###")
    return text[:idx].strip() if idx != -1 else text.strip()


def _call_hf_endpoint(prompt: str, *, max_new_tokens: int) -> str:
    print(
        f"Calling HF endpoint {ENDPOINT_NAME} for {len(prompt):,} prompt chars, "
        f"max_new_tokens={max_new_tokens}",
        flush=True,
    )
    for attempt in range(3):
        try:
            result = hf_client.text_generation(
                prompt,
                max_new_tokens=max_new_tokens,
                do_sample=False,
                repetition_penalty=1.05,
                return_full_text=False,
            )
            result = _truncate_at_prompt_marker(result)
            print(f"RAW MODEL OUTPUT: {result!r}", flush=True)
            return result
        except Exception as exc:
            if attempt == 2:
                raise
            wait_seconds = 5 * (attempt + 1)
            print(f"Endpoint generation failed ({exc}); retrying in {wait_seconds}s", flush=True)
            time.sleep(wait_seconds)


def _remote_generate_text(model, tokenizer, prompt: str, *, device, max_input_tokens: int, max_new_tokens: int) -> str:
    input_ids = tokenizer(
        prompt,
        add_special_tokens=False,
        truncation=True,
        max_length=max_input_tokens,
    ).input_ids
    truncated_prompt = tokenizer.decode(input_ids, skip_special_tokens=True)
    generated = _call_hf_endpoint(truncated_prompt, max_new_tokens=max_new_tokens)
    return summaries_blackwell._strip_prompt(generated)


def _remote_generate_batch(model, tokenizer, prompts: list[str], *, device, max_input_tokens: int, max_new_tokens: int) -> list[str]:
    # Filter out trivial prompts (heading-only chunks) before sending to the endpoint.
    results = [""] * len(prompts)
    work = [
        (i, p) for i, p in enumerate(prompts)
        if len(tokenizer(p, add_special_tokens=False).input_ids) >= MIN_CHUNK_TOKENS
    ]
    skipped = len(prompts) - len(work)
    if skipped:
        print(f"  skipping {skipped} trivial chunk(s) with < {MIN_CHUNK_TOKENS} tokens", flush=True)
    if not work:
        return results
    with ThreadPoolExecutor(max_workers=BATCH_SIZE) as executor:
        futures = {
            executor.submit(
                _remote_generate_text,
                model, tokenizer, prompt,
                device=device,
                max_input_tokens=max_input_tokens,
                max_new_tokens=max_new_tokens,
            ): idx
            for idx, prompt in work
        }
        for future, idx in futures.items():
            results[idx] = future.result()
    return results


summaries_blackwell._generate_text = _remote_generate_text
summaries_blackwell._generate_batch = _remote_generate_batch

model = hf_client
print("HF cloud generation is configured. No local generation model was loaded.")
# Out:
# HF cloud generation is configured. No local generation model was loaded.

# %%
from pathlib import Path

# Summarization configuration.
# Set BOOK_ID_TO_SUMMARIZE to one internal book_id for a single-book run.
# Leave it as None to resume through the first MAX_BOOKS unprocessed books.
BOOK_ID_TO_SUMMARIZE = 4037
MAX_BOOKS = 20
RUN_VALIDATION = True
SEMANTIC_THRESHOLD = 0.60
LEXICAL_FLOOR = 0.35
NLI_THRESHOLD = 0.50
CHUNK_TOKENS = 4096
CHUNK_OVERLAP = 400
REDUCE_INPUT_TOKENS = 8192
MAX_NEW_TOKENS = 512
REDUCE_MAX_NEW_TOKENS = 768
MAX_CHAPTERS = None
MAX_CHUNKS_PER_CHAPTER = None
BATCH_SIZE = 4
OUTPUT_PATH = Path.cwd()/ "Artifacts" / "summary_results_local.jsonl"
CHECKPOINT_DIR = Path.cwd() / "Artifacts" / "checkpoints"

OUTPUT_PATH.parent.mkdir(parents=True, exist_ok=True)
CHECKPOINT_DIR.mkdir(parents=True, exist_ok=True)

# %%
embedding_tokenizer = embedding_model = None
nli_tokenizer = nli_model = None
if RUN_VALIDATION:
    embedding_tokenizer, embedding_model = summaries_blackwell._load_embedding_model(
        summaries_blackwell.DEFAULT_EMBEDDING_MODEL_ID,
        HF_API_TOKEN,
    )
    nli_tokenizer, nli_model = summaries_blackwell._load_nli_model(
        summaries_blackwell.DEFAULT_NLI_MODEL_ID,
        HF_API_TOKEN,
    )


def summarize_one_book_via_hf_endpoint(book_id: int) -> dict | None:
    print(f"\nbook_id={book_id}", flush=True)
    try:
        book, book_desc_summary = _load_book_record(gcs_client, GCS_BUCKET, book_id)
    except FileNotFoundError as exc:
        print(f"  SKIP: {exc}", flush=True)
        return None

    mode = "verify" if book_desc_summary and RUN_VALIDATION else "generate"
    print(f"  mode={mode} title={book.title!r}", flush=True)
    print(f"  generation_endpoint={endpoint.url}", flush=True)

    checkpoint_path = str(CHECKPOINT_DIR / f"checkpoint_{book_id}.jsonl")

    result = summarize_book(
        model,
        tokenizer,
        book,
        device=None,
        chunk_tokens=CHUNK_TOKENS,
        chunk_overlap=CHUNK_OVERLAP,
        reduce_input_tokens=REDUCE_INPUT_TOKENS,
        max_new_tokens=MAX_NEW_TOKENS,
        reduce_max_new_tokens=REDUCE_MAX_NEW_TOKENS,
        batch_size=BATCH_SIZE,
        max_chapters=MAX_CHAPTERS,
        max_chunks_per_chapter=MAX_CHUNKS_PER_CHAPTER,
        story_so_far_tokens=REDUCE_MAX_NEW_TOKENS,
        checkpoint_path=checkpoint_path,
    )

    result["mode"] = mode
    result["book_desc_summary"] = book_desc_summary
    result["semantic_score"] = None
    result["lexical_score"] = None
    result["nli_contradiction_score"] = None
    result["similarity_pass"] = None

    # Print the final story-so-far (last chapter's running summary).
    if result.get("chapters"):
        final_story_so_far = result["chapters"][-1].get("story_so_far", "")
        if final_story_so_far:
            print("\nSTORY SO FAR (end of book)")
            print(final_story_so_far)

    print("\nFINAL SUMMARY")
    print(result["final_summary"])

    if RUN_VALIDATION and book_desc_summary:
        semantic = _semantic_similarity(embedding_tokenizer, embedding_model, result["final_summary"], book_desc_summary)
        lexical = _lexical_similarity(result["final_summary"], book_desc_summary)
        contradiction = _max_nli_contradiction(nli_tokenizer, nli_model, result["final_summary"], book_desc_summary)
        sem_pass = semantic >= SEMANTIC_THRESHOLD
        lex_pass = lexical >= LEXICAL_FLOOR
        nli_pass = contradiction < NLI_THRESHOLD
        sim_pass = sem_pass and (lex_pass or nli_pass)
        result.update({
            "semantic_score": semantic,
            "lexical_score": lexical,
            "nli_contradiction_score": contradiction,
            "similarity_pass": sim_pass,
        })
        print(
            f"  semantic={semantic:.3f} lexical={lexical:.3f}"
            f" nli_contradiction={contradiction:.3f} pass={sim_pass}",
            flush=True,
        )

    return result
# Out:
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 14580.76it/s]
# Loading weights: 100%|██████████| 106/106 [00:00<00:00, 20506.26it/s]

# %%
processed_ids: set[int] = set()
if OUTPUT_PATH.exists() and BOOK_ID_TO_SUMMARIZE is None:
    for line in OUTPUT_PATH.read_text(encoding="utf-8").splitlines():
        try:
            processed_ids.add(json.loads(line)["book_id"])
        except Exception:
            pass

if BOOK_ID_TO_SUMMARIZE is not None:
    book_ids_to_run = [BOOK_ID_TO_SUMMARIZE]
else:
    book_ids_to_run = [book_id for book_id in all_book_ids if book_id not in processed_ids]
    if MAX_BOOKS is not None:
        book_ids_to_run = book_ids_to_run[:MAX_BOOKS]

print(f"Already processed: {len(processed_ids)} books")
print(f"Running: {len(book_ids_to_run)} books via HF endpoint {ENDPOINT_NAME}")

for idx, book_id in enumerate(book_ids_to_run, 1):
    print(f"\n[{idx}/{len(book_ids_to_run)}]", flush=True)
    try:
        result = summarize_one_book_via_hf_endpoint(book_id)
    except Exception as exc:
        print(f"  ERROR summarizing: {exc}", flush=True)
        continue

    if result is None:
        continue

    with OUTPUT_PATH.open("a", encoding="utf-8") as handle:
        handle.write(json.dumps(result, ensure_ascii=False) + "\n")
    print(f"  saved -> {OUTPUT_PATH}", flush=True)

print("\nDone.")
# Out:
# Already processed: 0 books
# Running: 1 books via HF endpoint audiobook-summary-qwen25-7b
#
# [1/1]
#
# book_id=4037
# stage: loading content from gs://gutenberg-books/book-contents/4037/clean_content.txt
#   mode=verify title='Oliver Twist'
#   generation_endpoint=https://qa8zdn4a7x5ms3kt.us-east-1.aws.endpoints.huggingface.cloud
# stage: splitting book_id=4037 into chapters
# stage: found 54 chapter blocks
# stage: resumed from checkpoint — 39 chapters already done
# stage: chapter 1/54 skipped (checkpoint)
# stage: chapter 2/54 skipped (checkpoint)
# stage: chapter 3/54 skipped (checkpoint)
# stage: chapter 4/54 skipped (checkpoint)
# stage: chapter 5/54 skipped (checkpoint)
# stage: chapter 6/54 skipped (checkpoint)
# stage: chapter 7/54 skipped (checkpoint)
# stage: chapter 8/54 skipped (checkpoint)
# stage: chapter 9/54 skipped (checkpoint)
# stage: chapter 10/54 skipped (checkpoint)
# stage: chapter 11/54 skipped (checkpoint)
# stage: chapter 12/54 skipped (checkpoint)
# stage: chapter 13/54 skipped (checkpoint)
# stage: chapter 14/54 skipped (checkpoint)
# stage: chapter 15/54 skipped (checkpoint)
# stage: chapter 16/54 skipped (checkpoint)
# stage: chapter 17/54 skipped (checkpoint)
# stage: chapter 18/54 skipped (checkpoint)
# stage: chapter 19/54 skipped (checkpoint)
# stage: chapter 20/54 skipped (checkpoint)
# stage: chapter 21/54 skipped (checkpoint)
# stage: chapter 22/54 skipped (checkpoint)
# stage: chapter 23/54 skipped (checkpoint)
# stage: chapter 24/54 skipped (checkpoint)
# stage: chapter 25/54 skipped (checkpoint)
# stage: chapter 26/54 skipped (checkpoint)
# stage: chapter 27/54 skipped (checkpoint)
# stage: chapter 28/54 skipped (checkpoint)
# stage: chapter 29/54 skipped (checkpoint)
# stage: chapter 30/54 skipped (checkpoint)
# stage: chapter 31/54 skipped (checkpoint)
# stage: chapter 32/54 skipped (checkpoint)
# stage: chapter 33/54 skipped (checkpoint)
# stage: chapter 34/54 skipped (checkpoint)
# stage: chapter 35/54 skipped (checkpoint)
# stage: chapter 36/54 skipped (checkpoint)
# stage: chapter 37/54 skipped (checkpoint)
# stage: chapter 38/54 skipped (checkpoint)
# stage: chapter 39/54 skipped (checkpoint)
# stage: chapter 40/54 title='CHAPTER XXXIX.' length=29617
# stage: story_so_far (280 tokens):
# In *Oliver Twist* by Charles Dickens, the story follows the life of an orphan named Oliver Twist from his birth in a workhouse to his adventures in London. Oliver's journey begins with his birth and early years in the harsh conditions of the workhouse. He is eventually offered apprenticeships and befriended by a group of criminals led by Fagin, encountering various characters such as Mr. Brownlow, Nancy, and Monks along the way. Oliver faces numerous challenges and dangers, including being involved in a burglary and narrowly escaping capture. His character develops as he navigates the complexities of his life, ultimately leading to a resolution involving his true identity and the people who care for him. Key events include Oliver's time with Fagin and his friends, his interactions with Mr. Brownlow, and his eventual reunion with his long-lost family. The narrative includes a dramatic confrontation between Monks and Mr. Brownlow, followed by a pursuit and escape, and ends with Fagin's death. Throughout the novel, themes of poverty, injustice, and redemption are explored. Oliver's journey takes him through different parts of London, where he encounters various characters and faces numerous challenges, ultimately leading to a resolution involving his true identity and the people who care for him. The novel highlights the harsh realities of life in the Victorian era and the moral complexities of the criminal underworld. ###
# stage: chapter 40 chunk_count=3
# Calling HF endpoint audiobook-summary-qwen25-7b for 2,208 prompt chars, max_new_tokens=512
# Calling HF endpoint audiobook-summary-qwen25-7b for 17,161 prompt chars, max_new_tokens=512Calling HF endpoint audiobook-summary-qwen25-7b for 17,311 prompt chars, max_new_tokens=512
#
# RAW MODEL OUTPUT: 'In Chapter XXXIX of *Oliver Twist*, Nancy follows a man into a small ante-chamber lit by a lamp, as other maids express their opinions about materials. The man leaves Nancy alone after instructing her. This scene sets up a moment of tension and secrecy for Nancy.'
# RAW MODEL OUTPUT: "In Chapter XXXIX of *Oliver Twist*, Mr. William Sikes, a housebreaker, wakes up feeling weak and ill in a poorly furnished room. Nancy, his partner, tends to him, but Sikes becomes angry and strikes her. Fagin and the Artful Dodger arrive with a bundle of stolen goods, including food and alcohol, to help Sikes recover. Despite Sikes' initial anger, Fagin and the boys manage to soothe him. Sikes demands money from Fagin, who reluctantly agrees to send the Artful Dodger to retrieve it. Meanwhile, Toby Crackit and Mr. Chitling are playing cards, and Fagin sends the boys out to continue their criminal activities. The chapter highlights the deteriorating relationship between Sikes and Nancy, as well as the ongoing criminal activities of Fagin and his gang."
# RAW MODEL OUTPUT: "In Chapter XXXIX of *Oliver Twist*, Fagin sends the boys, Dodger and Charley, on a job while Nancy waits. When Monks arrives, Fagin brings him to a secret room to discuss news. Nancy overhears and becomes agitated, suspecting foul play. She returns home to Sikes, who notices her strange behavior. Nancy reveals she plans to deliver a message to Miss Maylie, a lady staying at a hotel. Despite initial resistance, the house staff agrees to pass the message, allowing Nancy to ascend to Miss Maylie's room."
# stage: chapter 40 summarized_chunks=3/3
# Calling HF endpoint audiobook-summary-qwen25-7b for 1,800 prompt chars, max_new_tokens=768
# RAW MODEL OUTPUT: "In Chapter XXXIX of *Oliver Twist*, Mr. William Sikes, a housebreaker, is found ill in a poorly furnished room. Nancy, his partner, cares for him, but he becomes angry and strikes her. Fagin and the Artful Dodger arrive with stolen goods, including food and alcohol, to help Sikes recover. Despite Sikes' initial anger, they manage to soothe him. Sikes demands money from Fagin, who sends the Artful Dodger to retrieve it. Meanwhile, Toby Crackit and Mr. Chitling are playing cards, and Fagin sends the boys out to continue their criminal activities. Nancy, agitated by overheard conversations, plans to deliver a message to Miss Maylie, a lady staying at a hotel. She ascends to Miss Maylie's room with the house staff's help. The chapter also includes a tense scene where Nancy follows a man into a small ante-chamber lit by a lamp. The deteriorating relationship between Sikes and Nancy, as well as the ongoing criminal activities of Fagin and his gang, are highlighted."
# Calling HF endpoint audiobook-summary-qwen25-7b for 34,992 prompt chars, max_new_tokens=768
# RAW MODEL OUTPUT:
'
# Calling HF endpoint audiobook-summary-qwen25-7b for 37,608 prompt chars, max_new_tokens=768
# RAW MODEL OUTPUT: "Cripples. Fagin's manipulation of Noah and Charlotte, as well as his strategic placement of them in the criminal world, are highlighted. The chapter also introduces a new character, Mr. Monks, who is described as a man with a sinister past and a connection to Oliver's identity. Monks is portrayed as a threat to Oliver's well-being, and his presence adds to the suspense and intrigue of the narrative."
# Calling HF endpoint audiobook-summary-qwen25-7b for 775 prompt chars, max_new_tokens=768
# RAW MODEL OUTPUT: 'In the latest chapter, Noah and Fagin devise a plan to steal money without revealing their identities. Noah introduces himself as "Mr. Morris Bolter" and his wife as "Mrs. Bolter," agreeing to meet the next day to finalize the details of the plan under this alias. This interaction showcases Fagin\'s cunning and Noah\'s readiness to engage in criminal activities.'
# Calling HF endpoint audiobook-summary-qwen25-7b for 1,016 prompt chars, max_new_tokens=768
# RAW MODEL OUTPUT: 'In the ongoing narrative of Oliver Twist, Fagin manipulates Noah and Charlotte, integrating them into his criminal network. A new character, Mr. Monks, emerges with a mysterious past linked to Oliver\'s identity, adding tension to the story. Meanwhile, Noah and Fagin plan to steal money under the alias of "Mr. Morris Bolter" and "Mrs. Bolter," demonstrating Fagin\'s cunning and Noah\'s willingness to participate in criminal activities. Mr. Monks\' involvement further heightens the suspense surrounding Oliver\'s background.'
# stage: chapter 44/54 title='CHAPTER XLIII.' length=21110
# stage: story_so_far (111 tokens):
# In the ongoing narrative of Oliver Twist, Fagin manipulates Noah and Charlotte, integrating them into his criminal network. A new character, Mr. Monks, emerges with a mysterious past linked to Oliver's identity, adding tension to the story. Meanwhile, Noah and Fagin plan to steal money under the alias of "Mr. Morris Bolter" and "Mrs. Bolter," demonstrating Fagin's cunning and Noah's willingness to participate in criminal activities. Mr. Monks' involvement further heightens the suspense surrounding Oliver's background.
# stage: chapter 44 chunk_count=2
# Calling HF endpoint audiobook-summary-qwen25-7b for 7,739 prompt chars, max_new_tokens=512
# Calling HF endpoint audiobook-summary-qwen25-7b for 16,606 prompt chars, max_new_tokens=512
# RAW MODEL OUTPUT: "In Chapter XLIII of *Oliver Twist*, Noah and Mr. Dawkins (the Dodger) appear in court. The Dodger, known for his wit and charm, behaves arrogantly and disruptively during the proceedings. When questioned about his actions, he claims to be an Englishman and demands his rights. The Dodger is accused of pickpocketing and is caught with a stolen snuffbox. Despite being convicted, he continues to mock the court and the authorities. Noah, who had been waiting outside, returns to inform Mr. Fagin that the Dodger is performing well in his criminal activities, establishing a reputation for himself. The scene highlights the Dodger's cleverness and defiance, while also emphasizing the corrupt nature of the legal system."
# RAW MODEL OUTPUT: "In Chapter XLIII of *Oliver Twist*, Fagin discusses his criminal operations with Noah (now called Mr. Bolter), emphasizing the importance of mutual trust and loyalty. Fagin reveals that his best accomplice, the Artful Dodger, has been arrested and is facing charges for attempted pickpocketing. Despite the Dodger's capture, Fagin remains optimistic about his future, believing he will receive a fair trial and be treated well in prison. Charley Bates, another of Fagin's associates, arrives to inform Fagin that the Dodger is booked for transportation. Fagin plans to visit the police station disguised as a waggoner to gather information about the Dodger's condition. Noah agrees to make the trip, dressing in a waggoner's outfit and following detailed instructions provided by Fagin. Upon arriving at Bow Street, Noah finds the police station and successfully locates the Dodger in the dock, confirming his suspicions. The chapter highlights the criminal underworld's dynamics and the lengths to which Fagin goes to protect his associates."
# stage: chapter 44 summarized_chunks=2/2
# Calling HF endpoint audiobook-summary-qwen25-7b for 2,026 prompt chars, max_new_tokens=768
# RAW MODEL OUTPUT: "